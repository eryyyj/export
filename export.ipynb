# %%
from ultralytics import YOLO

model = YOLO('YOLOshrimp.pt')
model.export(format='imx')
# Out:
# Ultralytics 8.3.222 🚀 Python-3.10.19 torch-2.9.0+cu128 CPU (Intel Celeron N4100 CPU @ 1.10GHz)
# WARNING ⚠️ IMX export requires int8=True, setting int8=True.
# WARNING ⚠️ IMX export requires nms=True, setting nms=True.
# WARNING ⚠️ INT8 export requires a missing 'data' arg for calibration. Using default 'data=coco8.yaml'.
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLO11shrimp summary (fused): 100 layers, 4,519,156 parameters, 0 gradients, 10.8 GFLOPs
# [W1030 21:43:49.641257136 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1030 21:43:49.646263585 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1030 21:43:49.647370434 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1030 21:43:49.649025411 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# ...
